# %% [markdown]
# # Importa bibliotecas

# %%
import pandas as pd

# %% [markdown]
# # Importa arquivo para pandas

# %%
df = pd.read_csv('ArquivosFTP/AC2010.txt', sep = ';', encoding='latin1')

# %%
df
# Out:
#                   Bairros SP     Bairros Fortaleza            Bairros RJ  \
# 0                        NaN             {ñ class}             {ñ class}
# 1                  {ñ class}             {ñ class}             {ñ class}
# 2                  {ñ class}             {ñ class}             {ñ class}
# 3                  {ñ class}             {ñ class}             {ñ class}
# 4                  {ñ class}             {ñ class}             {ñ class}
# ...                      ...                   ...                   ...
# 162143             {ñ class}             {ñ class}             {ñ class}
# 162144             {ñ class}             {ñ class}             {ñ class}
# 162145             {ñ class}             {ñ class}             {ñ class}
# 162146             {ñ class}             {ñ class}             {ñ class}
# 162147             {ñ class}             {ñ class}             {ñ class}
#
#         Causa Afastamento 1  Causa Afastamento 2  Causa Afastamento 3  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162148 entries, 0 to 162147
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Bairros SP               162147 non-null  object
#  1   Bairros Fortaleza        162148 non-null  object
#  2   Bairros RJ               162148 non-null  object
#  3   Causa Afastamento 1      162148 non-null  int64
#  4   Causa Afastamento 2      162148 non-null  int64
#  5   Causa Afastamento 3      162148 non-null  int64
#  6   Motivo Desligamento      162148 non-null  int64
#  7   CBO Ocupação 2002        162148 non-null  int64
#  8   CNAE 2.0 Classe          162148 non-null  int64
#  9   CNAE 95 Classe           162148 non-null  int64
#  10  Distritos SP             162148 non-null  object
#  11  Vínculo Ativo 31/12      162148 non-null  int64
#  12  Faixa Etária             162148 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['Bairros SP', 'Bairros Fortaleza', 'Bairros RJ', 'Causa Afastamento 1',
#        'Causa Afastamento 2', 'Causa Afastamento 3', 'Motivo Desligamento',
#        'CBO Ocupação 2002', 'CNAE 2.0 Classe', 'CNAE 95 Classe',
#        'Distritos SP', 'Vínculo Ativo 31/12', 'Faixa Etária',
#        'Faixa Hora Contrat', 'Faixa Remun Dezem (SM)',
#        'Faixa Remun Média (SM)', 'Faixa Tempo Emprego',
#        'Escolaridade após 2005', 'Qtd Hora Contr', 'Idade',
#        'Ind CEI Vinculado', 'Ind Simples', 'Mês Admissão', 'Mês Desligamento',
#        'Mun Trab', 'Município', 'Nacionalidade', 'Natureza Jurídica',
#        'Ind Portador Defic', 'Qtd Dias Afastamento', 'Raça Cor',
#        'Regiões Adm DF', 'Vl Remun Dezembro Nom', 'Vl Remun Dezembro (SM)',
#        'Vl Remun Média Nom', 'Vl Remun Média (SM)', 'CNAE 2.0 Subclasse',
#        'Sexo Trabalhador', 'Tamanho Estabelecimento', 'Tempo Emprego',
#        'Tipo Admissão', 'Tipo Estab', 'Tipo Estab.1', 'Tipo Defic',
# ...

# %%
df.describe()

#count = quadntidade de registros
# Out:
#        Causa Afastamento 1  Causa Afastamento 2  Causa Afastamento 3  \
# count        162148.000000             162148.0             162148.0
# mean             98.999698                 99.0                 99.0
# std               0.121686                  0.0                  0.0
# min              50.000000                 99.0                 99.0
# 25%              99.000000                 99.0                 99.0
# 50%              99.000000                 99.0                 99.0
# 75%              99.000000                 99.0                 99.0
# max              99.000000                 99.0                 99.0
#
#        Motivo Desligamento  CBO Ocupação 2002  CNAE 2.0 Classe  \
# count        162148.000000      162148.000000    162148.000000
# mean              3.565903      468593.211560     62439.094124
# std               6.963100      200490.642833     24965.961515
# min               0.000000       10105.000000      1113.000000
# ...

# %%
print(df['Causa Afastamento 1'].unique())
# Out:
# [99 50]

# %%
print(df['Causa Afastamento 2'].unique())
# Out:
# [99]

# %%
df.shape
# Out:
# (162148, 45)

# %%
df['UF'] = 'AC'
df
# Out:
#                   Bairros SP     Bairros Fortaleza            Bairros RJ  \
# 0                        NaN             {ñ class}             {ñ class}
# 1                  {ñ class}             {ñ class}             {ñ class}
# 2                  {ñ class}             {ñ class}             {ñ class}
# 3                  {ñ class}             {ñ class}             {ñ class}
# 4                  {ñ class}             {ñ class}             {ñ class}
# ...                      ...                   ...                   ...
# 162143             {ñ class}             {ñ class}             {ñ class}
# 162144             {ñ class}             {ñ class}             {ñ class}
# 162145             {ñ class}             {ñ class}             {ñ class}
# 162146             {ñ class}             {ñ class}             {ñ class}
# 162147             {ñ class}             {ñ class}             {ñ class}
#
#         Causa Afastamento 1  Causa Afastamento 2  Causa Afastamento 3  \
# ...

# %%
df['ANO'] = 2010
df
# Out:
#                   Bairros SP     Bairros Fortaleza            Bairros RJ  \
# 0                        NaN             {ñ class}             {ñ class}
# 1                  {ñ class}             {ñ class}             {ñ class}
# 2                  {ñ class}             {ñ class}             {ñ class}
# 3                  {ñ class}             {ñ class}             {ñ class}
# 4                  {ñ class}             {ñ class}             {ñ class}
# ...                      ...                   ...                   ...
# 162143             {ñ class}             {ñ class}             {ñ class}
# 162144             {ñ class}             {ñ class}             {ñ class}
# 162145             {ñ class}             {ñ class}             {ñ class}
# 162146             {ñ class}             {ñ class}             {ñ class}
# 162147             {ñ class}             {ñ class}             {ñ class}
#
#         Causa Afastamento 1  Causa Afastamento 2  Causa Afastamento 3  \
# ...
